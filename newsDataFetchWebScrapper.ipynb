# %% [markdown]
# <a href="https://colab.research.google.com/github/rivalsolmons/WebScrapper/blob/main/newsDataFetchWebScrapper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pygooglenews --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from pygooglenews import GoogleNews

# %%
gn = GoogleNews(country = 'IND')


def get_titles(search):
    stories = []
    search = gn.search(search)
    newsitem = search['entries']
    for item in newsitem:
        story = {
            'title': item.title,
            'link' : item.link
        }
        stories.append(story)
    return stories

print(get_titles('Fraud'))
# Out:
# [{'title': '2 ex-NBA players sentenced to prison for their roles in $4M fraudulent benefits scheme - Yahoo Sports', 'link': 'https://news.google.com/rss/articles/CBMifWh0dHBzOi8vc3BvcnRzLnlhaG9vLmNvbS8yLWV4LW5iYS1wbGF5ZXJzLXNlbnRlbmNlZC10by1wcmlzb24tZm9yLXRoZWlyLXJvbGVzLWluLTRtLWZyYXVkdWxlbnQtYmVuZWZpdHMtc2NoZW1lLTIzMTQxODg3NS5odG1s0gEA?oc=5'}, {'title': 'Former Mizzou guard Keyon Dooling sentenced in NBA fraud scheme - WDAF FOX4 Kansas City', 'link': 'https://news.google.?oc=5'}, {'title': 'Ex-NBA Players Sentenced to Prison After Multimillion Dollar Fraud Scheme - Sports Illustrated', 'link': 'https://news.google.com/rss/articles/CBMia2h0dHBzOi8vd3d3LnNpLmNvbS9uYmEvMjAyMy8wMi
# ...

# %%
gn = GoogleNews(country = 'IND')


def get_titles(search):
    stories = []
    search = gn.search(search)
    newsitem = search['entries']
    for item in newsitem:
        story = {
            'title': item.title,
            
        }
        stories.append(story)
    return stories

print(get_titles('Fraud'))
# Out:
# [{'title': '2 ex-NBA players sentenced to prison for their roles in $4M fraudulent benefits scheme - Yahoo Sports'}, {'title': 'Former Mizzou guard Keyon Dooling sentenced in NBA fraud scheme - WDAF FOX4 Kansas City'}, {'title': 'Ex-NBA Players Sentenced to Prison After Multimillion Dollar Fraud Scheme - Sports Illustrated'}, {'title': 'In Canada, complex fraud schemes are targeting homeowners - BBC'}, {'title': 'Lodi city council member Shakir Khan arrested, now faces voter fraud charges - CBS Sacramento'}, {'title': 'Orange County woman’s 6-month gambling spree at Wynn Las Vegas funded by $10M fraud scheme, lawsuit alleges - KTLA Los Angeles'}, {'title': 'Paradise Valley man pleads guilty to $50 million tax fraud scheme - KTAR.com'}, {'title': 'SEC charges Do Kwon, Terraform with fraud in connection with Terra collapse - CNBC'}, {'title': 'Justice Department left to mop up after flood of PPP fraud in Philadelphia and across the nation - The Business Journals'}, {'title': 'Jen Shah 
# ...

# %%
gn = GoogleNews(country = 'IND')


def get_titles(search):
    stories = []
    search = gn.search(search)
    newsitem = search['entries']
    for item in newsitem:
        story = {
            
            'link' : item.link
        }
        stories.append(story)
    return stories

print(get_titles('Fraud'))
# Out:
# [{'link': 'https://news.google.com/rss/articles/CBMifWh0dHBzOi8vc3BvcnRzLnlhaG9vLmNvbS8yLWV4LW5iYS1wbGF5ZXJzLXNlbnRlbmNlZC10by1wcmlzb24tZm9yLXRoZWlyLXJvbGVzLWluLTRtLWZyYXVkdWxlbnQtYmVuZWZpdHMtc2NoZW1lLTIzMTQxODg3NS5odG1s0gEA?oc=5'}, {'link': 'https://news.google.?oc=5'}, {'link': 'https://news.google.?oc=5'}, {'link': 'https://news.google.com/rss/articles/CBMiMWh0d
# ...
